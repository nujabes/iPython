# %% [markdown]
# # WEBGL 기초 셋업

# %%
# %%html
# <canvas id="ex1"></canvas>
# <script>
# var gl = document.querySelector('#ex1').getContext('webgl');
# gl.canvas.width = 200;
# gl.canvas.height = 200;
# gl.clearColor(1, 0, 0, 1);
# gl.clear(gl.COLOR_BUFFER_BIT);
# </script>
# Out:
# <canvas id="ex1"></canvas>
# <script>
# var gl = document.querySelector('#ex1').getContext('webgl');
# gl.canvas.width = 200;
# gl.canvas.height = 200;
# gl.clearColor(1, 0, 0, 1);
# gl.clear(gl.COLOR_BUFFER_BIT);
# </script>

# %% [markdown]
# ## vertex shader

# %%
# %%html
# <canvas id="ex2"></canvas>
# <script id="vs2" type="x-shader/x-vertex-shader">
#     attribute vec2 a_pos;
#     void main() {
#         gl_Position = vec4(a_pos, 0.0, 1.0);
#     }
# </script>
# <script id="fs2" type="x-shader/x-fragment-shader">
#     precision mediump float;
#     uniform vec2 resolution;
#     void main() {
#         gl_FragColor = vec4(1.0, 0.0, 0.0, 1.0);
#     }
# </script>
# <script>
#     var gl = document.querySelector('#ex2').getContext('webgl');
#     gl.canvas.width = 200;
#     gl.canvas.height = 200;
#     gl.clearColor(0, 0, 0, 1);
#     gl.clear(gl.COLOR_BUFFER_BIT);
#     gl.viewport(0, 0, gl.canvas.width, gl.canvas.height);
#
#     var vs = gl.createShader(gl.VERTEX_SHADER);
#     var vsSrc = document.querySelector('#vs2').textContent;
#
#     var fs = gl.createShader(gl.FRAGMENT_SHADER);
#     var fsSrc = document.querySelector('#fs2').textContent;
#
#     gl.shaderSource(vs, vsSrc);
#     gl.compileShader(vs);
#     gl.shaderSource(fs, fsSrc);
#     gl.compileShader(fs);
#
#     if(!gl.getShaderInfoLog(vs)){
#         console.log(gl.getShaderInfoLog(vs));
#     };
#     if(!gl.getShaderInfoLog(fs)){
#         console.log(gl.getShaderInfoLog(fs));
#     };
#
#     var prog = gl.createProgram();
#     gl.attachShader(prog, vs);
#     gl.attachShader(prog, fs);
#     gl.linkProgram(prog);
#     if(!gl.getProgramInfoLog(prog)){
#         console.log(gl.getProgramInfoLog(prog));
#     };
#
#     var a_pos = gl.getAttribLocation(prog, 'a_pos');
#     gl.enableVertexAttribArray(a_pos);
#     var vb = gl.createBuffer();
#     gl.bindBuffer(gl.ARRAY_BUFFER, vb);
#     var vb_data = new Float32Array([-1, -1, 1, -1, -1, 1, 1, 1]);
#     gl.bufferData(gl.ARRAY_BUFFER, vb_data, gl.STATIC_DRAW);
#     gl.useProgram(prog);
#     var u_resolution = gl.getUniformLocation(prog, 'resolution');
#     gl.uniform2f(u_resolution, gl.canvas.width, gl.canvas.height);
#     gl.vertexAttribPointer(a_pos, 2, gl.FLOAT, false, 0, 0);
#
#     gl.drawArrays(gl.TRIANGLE_STRIP, 0, 4);
# </script>
# Out:
# <canvas id="ex2"></canvas>
# <script id="vs2" type="x-shader/x-vertex-shader">
#     attribute vec2 a_pos;
#     void main() {
#         gl_Position = vec4(a_pos, 0.0, 1.0);
#     }
# </script>
# <script id="fs2" type="x-shader/x-fragment-shader">
#     precision mediump float;
#     uniform vec2 resolution;
#     void main() {
#         gl_FragColor = vec4(1.0, 0.0, 0.0, 1.0);
#     }
# </script>
# <script>
#     var gl = document.querySelector('#ex2').getContext('webgl');
#     gl.canvas.width = 200;
#     gl.canvas.height = 200;
#     gl.clearColor(0, 0, 0, 1);
#     gl.clear(gl.COLOR_BUFFER_BIT);
#     gl.viewport(0, 0, gl.canvas.width, gl.canvas.height);
#
#     var vs = gl.createShader(gl.VERTEX_SHADER);
#     var vsSrc = document.querySelector('#vs2').textContent;
#
#     var fs = gl.createShader(gl.FRAGMENT_SHADER);
#     var fsSrc = document.querySelector('#fs2').textContent;
#
#     gl.shaderSource(vs, vsSrc);
#     gl.compileShader(vs);
#     gl.shaderSource(fs, fsSrc);
#     gl.compileShader(fs);
#
#     if(!gl.getShaderInfoLog(vs)){
#         console.log(gl.getShaderInfoLog(vs));
#     };
#     if(!gl.getShaderInfoLog(fs)){
#         console.log(gl.getShaderInfoLog(fs));
#     };
#
#     var prog = gl.createProgram();
#     gl.attachShader(prog, vs);
#     gl.attachShader(prog, fs);
#     gl.linkProgram(prog);
#     if(!gl.getProgramInfoLog(prog)){
#         console.log(gl.getProgramInfoLog(prog));
#     };
#
#     var a_pos = gl.getAttribLocation(prog, 'a_pos');
#     gl.enableVertexAttribArray(a_pos);
#     var vb = gl.createBuffer();
#     gl.bindBuffer(gl.ARRAY_BUFFER, vb);
#     var vb_data = new Float32Array([-1, -1, 1, -1, -1, 1, 1, 1]);
#     gl.bufferData(gl.ARRAY_BUFFER, vb_data, gl.STATIC_DRAW);
#     gl.useProgram(prog);
#     var u_resolution = gl.getUniformLocation(prog, 'resolution');
#     gl.uniform2f(u_resolution, gl.canvas.width, gl.canvas.height);
#     gl.vertexAttribPointer(a_pos, 2, gl.FLOAT, false, 0, 0);
#
#     gl.drawArrays(gl.TRIANGLE_STRIP, 0, 4);
# </script>

# %%
# %%html
# <canvas id="ex3"></canvas>
# <script id="vs3" type="x-shader/x-vertex-shader">
#     attribute vec2 a_pos;
#     void main() {
#         gl_Position = vec4(a_pos, 0.0, 1.0);
#     }
# </script>
# <script id="fs3" type="x-shader/x-fragment-shader">
#     precision mediump float;
#     uniform vec2 resolution;
#     void main() {
#         gl_FragColor = vec4(0.0, 1.0, 0.0, 1.0);
#     }
# </script>
# <script>
#     var gl = document.querySelector('#ex3').getContext('webgl');
#     gl.canvas.width = 200;
#     gl.canvas.height = 200;
#     gl.clearColor(0, 0, 0, 1);
#     gl.clear(gl.COLOR_BUFFER_BIT);
#     gl.viewport(0, 0, gl.canvas.width, gl.canvas.height);
#
#     var vs = gl.createShader(gl.VERTEX_SHADER);
#     var vsSrc = document.querySelector('#vs3').textContent;
#
#     var fs = gl.createShader(gl.FRAGMENT_SHADER);
#     var fsSrc = document.querySelector('#fs3').textContent;
#
#     gl.shaderSource(vs, vsSrc);
#     gl.compileShader(vs);
#     gl.shaderSource(fs, fsSrc);
#     gl.compileShader(fs);
#
#     if(!gl.getShaderInfoLog(vs)){
#         console.log(gl.getShaderInfoLog(vs));
#     };
#     if(!gl.getShaderInfoLog(fs)){
#         console.log(gl.getShaderInfoLog(fs));
#     };
#
#     var prog = gl.createProgram();
#     gl.attachShader(prog, vs);
#     gl.attachShader(prog, fs);
#     gl.linkProgram(prog);
#     if(!gl.getProgramInfoLog(prog)){
#         console.log(gl.getProgramInfoLog(prog));
#     };
#
#     var a_pos = gl.getAttribLocation(prog, 'a_pos');
#     gl.enableVertexAttribArray(a_pos);
#     var vb = gl.createBuffer();
#     gl.bindBuffer(gl.ARRAY_BUFFER, vb);
#     var vb_data = new Float32Array([-1, -1, 1, -1, -1, 1, 1, 1]);
#     gl.bufferData(gl.ARRAY_BUFFER, vb_data, gl.STATIC_DRAW);
#     gl.useProgram(prog);
#     var u_resolution = gl.getUniformLocation(prog, 'resolution');
#     gl.uniform2f(u_resolution, gl.canvas.width, gl.canvas.height);
#     gl.vertexAttribPointer(a_pos, 2, gl.FLOAT, false, 0, 0);
#
# //    gl.drawArrays(gl.TRIANGLE_STRIP, 0, 4);
#     gl.drawArrays(gl.TRIANGLE_STRIP, 0, 3);
# </script>
# Out:
# <canvas id="ex3"></canvas>
# <script id="vs3" type="x-shader/x-vertex-shader">
#     attribute vec2 a_pos;
#     void main() {
#         gl_Position = vec4(a_pos, 0.0, 1.0);
#     }
# </script>
# <script id="fs3" type="x-shader/x-fragment-shader">
#     precision mediump float;
#     uniform vec2 resolution;
#     void main() {
#         gl_FragColor = vec4(0.0, 1.0, 0.0, 1.0);
#     }
# </script>
# <script>
#     var gl = document.querySelector('#ex3').getContext('webgl');
#     gl.canvas.width = 200;
#     gl.canvas.height = 200;
#     gl.clearColor(0, 0, 0, 1);
#     gl.clear(gl.COLOR_BUFFER_BIT);
#     gl.viewport(0, 0, gl.canvas.width, gl.canvas.height);
#
#     var vs = gl.createShader(gl.VERTEX_SHADER);
#     var vsSrc = document.querySelector('#vs3').textContent;
#
#     var fs = gl.createShader(gl.FRAGMENT_SHADER);
#     var fsSrc = document.querySelector('#fs3').textContent;
#
#     gl.shaderSource(vs, vsSrc);
#     gl.compileShader(vs);
#     gl.shaderSource(fs, fsSrc);
#     gl.compileShader(fs);
#
#     if(!gl.getShaderInfoLog(vs)){
#         console.log(gl.getShaderInfoLog(vs));
#     };
#     if(!gl.getShaderInfoLog(fs)){
#         console.log(gl.getShaderInfoLog(fs));
#     };
#
#     var prog = gl.createProgram();
#     gl.attachShader(prog, vs);
#     gl.attachShader(prog, fs);
#     gl.linkProgram(prog);
#     if(!gl.getProgramInfoLog(prog)){
#         console.log(gl.getProgramInfoLog(prog));
#     };
#
#     var a_pos = gl.getAttribLocation(prog, 'a_pos');
#     gl.enableVertexAttribArray(a_pos);
#     var vb = gl.createBuffer();
#     gl.bindBuffer(gl.ARRAY_BUFFER, vb);
#     var vb_data = new Float32Array([-1, -1, 1, -1, -1, 1, 1, 1]);
#     gl.bufferData(gl.ARRAY_BUFFER, vb_data, gl.STATIC_DRAW);
#     gl.useProgram(prog);
#     var u_resolution = gl.getUniformLocation(prog, 'resolution');
#     gl.uniform2f(u_resolution, gl.canvas.width, gl.canvas.height);
#     gl.vertexAttribPointer(a_pos, 2, gl.FLOAT, false, 0, 0);
#
# //    gl.drawArrays(gl.TRIANGLE_STRIP, 0, 3);
#     gl.drawArrays(gl.TRIANGLE_STRIP, 0, 3);
# </script>
